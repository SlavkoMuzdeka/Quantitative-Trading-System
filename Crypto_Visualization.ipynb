# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('./Data/crypto/lbmom_strat.csv')
df2 = pd.read_csv('./Data/crypto/lsmom_strat.csv')

# %%
df.head()
# Out:
#    Unnamed: 0        date       capital  strat scalar  BTC-USD units  \
# 0           0  2021-01-22  10000.000000           2.0       0.006081
# 1           1  2021-01-23  10047.667948           2.0       0.006234
# 2           2  2021-01-24  10076.693157           2.0       0.006297
# 3           3  2021-01-25  10028.390276           2.0       0.006252
# 4           4  2021-01-26  10069.509895           2.0       0.006240
#
#    ETH-USD units  LTC-USD units  XMR-USD units  XRP-USD units  ADA-USD units  \
# 0       0.109789       1.156892            0.0            0.0     322.330525
# 1       0.110706       0.000000            0.0            0.0     328.550121
# 2       0.095236       0.000000            0.0            0.0     325.263283
# 3       0.098597       0.000000            0.0            0.0       0.000000
# 4       0.096998       0.000000            0.0            0.0       0.000000
#
#    ...  ALGO-USD w  EOS-USD w  FTM-USD w  XTZ-USD w  NEO-USD w      nominal  \
# 0  ...    0.051588        0.0   0.000000   0.057188   0.080146  1923.014224
# 1  ...    0.061105        0.0   0.000000   0.072421   0.096709  1618.947866
# 2  ...    0.060413        0.0   0.000000   0.088294   0.095390  1655.832011
# 3  ...    0.063669        0.0   0.052396   0.092023   0.099786  1562.204480
# 4  ...    0.074104        0.0   0.050481   0.103102   0.106224  1469.396270
#
#    leverage  daily pnl  nominal ret  capital ret
# 0  0.192301        NaN          NaN          NaN
# 1  0.161127  47.667948     0.024788     0.004767
# 2  0.164323  29.025209     0.017928     0.002889
# 3  0.155778 -48.302881    -0.029171    -0.004794
# 4  0.145925  41.119619     0.026322     0.004100
#
# [5 rows x 53 columns]

# %%
# Plotting capital over time
plt.figure(figsize=(10, 6))
plt.plot(df['date'], df['capital'], label='Capital Over Time', color='blue')
plt.title('Capital Over Time')
plt.xlabel('Time')
plt.ylabel('Capital')
plt.legend()
plt.grid(True)
plt.show()

# %%
# Plotting Daily P&L
plt.figure(figsize=(10, 6))
plt.plot(df['date'], df['daily pnl'], label='Daily P&L', color='green')
plt.title('Daily P&L Over Time')
plt.xlabel('Time')
plt.ylabel('Daily P&L')
plt.legend()
plt.grid(True)
plt.show()

# %%
# Plotting Leverage Over Time
plt.figure(figsize=(10, 6))
plt.plot(df['date'], df['leverage'], label='Leverage Over Time', color='purple')
plt.title('Leverage Over Time')
plt.xlabel('Time')
plt.ylabel('Leverage')
plt.legend()
plt.grid(True)
plt.show()

# %%
# Comparison of LBmom and LSmom capital over time
plt.figure(figsize=(10, 6))
plt.plot(df['date'], df['capital'], label='LBmom strategy', color='orange')
plt.plot(df2['date'], df2['capital'], label='LSmom strategy', color='blue')
plt.title('Comparison of Capital Over Time')
plt.xlabel('Time')
plt.ylabel('Capital')
plt.legend()
plt.grid(True)
plt.show()

# %%
df['daily_return'] = df['capital'].pct_change()

average_daily_return = df['daily_return'].mean()

risk_free_rate = 0.0

std_dev_daily_return = df['daily_return'].std()

sharpe_ratio = (average_daily_return - risk_free_rate) / std_dev_daily_return

print("Sharpe Ratio:", sharpe_ratio)
# Out:
# Sharpe Ratio: 0.035679589495945456
